# %%
from load_intan.load_intan_rhd_format import experiment
import numpy as np
import matplotlib.pyplot as plt

# %%
# %%capture
exp1 = experiment("18hr after surgery", "/Users/sean/Seans Mac Pro/KUMED/Research Internship/Experiment/241111 invivo/241112 12pm/241112 11_45am_241112_114711")

# %%
a = exp1.getdata_list()

# %%
y_min, y_max = -300, 300

# %%
exp1.show_data(2)
